# %% [markdown]
# # Sentiment Classification using NLP and Classification Algorithm

# %% [markdown]
# Sentiment Analysis is a means to identofy the view or emotion behind a situation.
#
# It basically means to analyse and find the emotion or intent behind a piece of text or speech or any model of communication.
#
# This burger has a very bad taste- negative review
#
# I ordered this pizza today- nutral sentiment/review
#
# I love this cheese sandwich, its so delicious- positive review

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
df_train=pd.read_csv("train.txt",delimiter=";",names=['text','label'])
df_val=pd.read_csv("val.txt",delimiter=";",names=['text','label'])

# %%
df=pd.concat([df_train, df_val])
df.reset_index(inplace=True, drop=True)

# %%
print("Shape of the dataframe: ",df.shape)
df.sample(5)
# Out:
# Shape of the dataframe:  (18000, 2)
#                                                     text    label
# 12241              i am left feeling unsure and confused     fear
# 2564                              im feeling very gloomy  sadness
# 13256  i feel like affirmation however petty is what ...    anger
# 17915  i must admit by the time i got back dripping i...  sadness
# 747    i havent worked out today but i feel like im j...    anger

# %%
import warnings
warnings.filterwarnings("ignore")

sns.countplot(df.label)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# Positve Sentiment- joy, love, surprise
#
# Negative sentiment- anger, sadness, fear
#
# Now we will create a custom encoder to convert categorical target labels to numerical i.e 0 and 1

# %%
def custom_encoder(df):
    df.replace(to_replace="surprise",value=1, inplace=True)
    df.replace(to_replace="love",value=1, inplace=True)
    df.replace(to_replace="joy",value=1, inplace=True)
    df.replace(to_replace="fear",value=0, inplace=True)
    df.replace(to_replace="anger",value=0, inplace=True)
    df.replace(to_replace="sadness",value=0, inplace=True)

# %%
custom_encoder(df['label'])

# %%
sns.countplot(df.label)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# Preprocessing Steps
#
# Get rid of any characters apart from alphabets
#
# Convert the string to lowercase because Python is case-sensitive
#
# Check and remove the stopwords
#
# Perform lemmatization

# %%
lm=WordNetLemmatizer()

# %%
def text_transformation(df_col):
    corpus=[]
    for item in df_col:
        new_item=re.sub('[^a-zA-Z]',' ',str(item))
        new_item=new_item.lower()
        new_item=new_item.split()
        new_item=[lm.lemmatize(word) for word in new_item if word not in set(stopwords.words('english'))]
        corpus.append(' '.join(str(x) for x in new_item))
    return corpus

# %%
corpus=text_transformation(df['text'])

# %%
cv=CountVectorizer(ngram_range=(1,2))
traindata=cv.fit_transform(corpus)
X=traindata
y=df.label

# %% [markdown]
# Now we will fit the data into gri search and view the best parameters using the best_params attribute

# %%
parameters={'max_features':('auto','sqrt'),
            'n_estimators':[5,10],
            'max_depth':[10,None],
            'min_samples_split':[5],
            'min_samples_leaf':[1],
            'bootstrap':[True]
           }

# %%
grid_search=GridSearchCV(RandomForestClassifier(), parameters, cv=5, return_train_score=True,n_jobs=-1)
grid_search.fit(X,y)
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 10}

# %% [markdown]
# We can view all the models and their respective parameters, mean test score and rank as GridSearch CV

# %%
for i in range(8):
    print('Parameters: ', grid_search.cv_results_['params'][i])
    print('Mean test Score: ',grid_search.cv_results_['mean_test_score'][i])
    print("Rank: ",grid_search.cv_results_['rank_test_score'])
# Out:
# Parameters:  {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 5}
# Mean test Score:  0.6001666666666667
# Rank:  [7 5 8 6 4 2 3 1]
# Parameters:  {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 10}
# Mean test Score:  0.6304444444444445
# Rank:  [7 5 8 6 4 2 3 1]
# Parameters:  {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 5}
# Mean test Score:  0.5979444444444445
# Rank:  [7 5 8 6 4 2 3 1]
# Parameters:  {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 10}
# Mean test Score:  0.6193888888888889
# Rank:  [7 5 8 6 4 2 3 1]
# Parameters:  {'bootstrap': True, 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 5}
# Mean test Score:  0.9081666666666667
# Rank:  [7 5 8 6 4 2 3 1]
# Parameters:  {'bootstrap': True, 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 10}
# Mean test Score:  0.9355
# Rank:  [7 5 8 6 4 2 3 1]
# Parameters:  {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 5}
# Mean test Score:  0.9141666666666668
# Rank:  [7 5 8 6 4 2 3 1]
# Parameters:  {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 10}
# Mean test Score:  0.9364444444444444
# Rank:  [7 5 8 6 4 2 3 1]

# %% [markdown]
# Now we will choose the best parameter obtained from GridSearchCV and create a final random forest classifier model and then train our model.

# %%
rfc= RandomForestClassifier(max_features=grid_search.best_params_['max_features'],
                           max_depth=grid_search.best_params_['max_depth'],
                           n_estimators=grid_search.best_params_['n_estimators'],
                           min_samples_split=grid_search.best_params_['min_samples_split'],
                           min_samples_leaf=grid_search.best_params_['min_samples_leaf'],
                           bootstrap=grid_search.best_params_['bootstrap'])

rfc.fit(X,y)
# Out:
# RandomForestClassifier(max_features='sqrt', min_samples_split=5,
#                        n_estimators=10)

# %% [markdown]
# Test Data Transformation

# %%
test_df=pd.read_csv('test.txt',delimiter=';',names=['text','label'])

# %%
X_test, y_test=test_df.text, test_df.label

# encode the labels into two classes 0 and 1
test_df= custom_encoder(y_test)

# preprocessing of text
test_corpus=text_transformation(X_test)

# convert the text data into vectors
testdata=cv.transform(test_corpus)

#predict the target
predictions=rfc.predict(testdata)

# %% [markdown]
# Model Evaluation
#
# We will evaluate our model using various metrics such as accuracy score, precision score, recall score confusion matrix.

# %%
acc_score= accuracy_score(y_test, predictions)
pre_score= precision_score(y_test, predictions)
rec_score=recall_score(y_test, predictions)

print('Accuracy Score:',acc_score)
print("Precision Score:",pre_score)
print('Recall Score',rec_score)

print("-"*50)

cr=classification_report(y_test, predictions)
print(cr)
# Out:
# Accuracy Score: 0.948
# Precision Score: 0.9513274336283186
# Recall Score 0.9347826086956522
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      1080
#            1       0.95      0.93      0.94       920
#
#     accuracy                           0.95      2000
#    macro avg       0.95      0.95      0.95      2000
# weighted avg       0.95      0.95      0.95      2000

# %% [markdown]
# ROC Curve- We will plot probability of the class using the predict_proba() method of random forest classifier and then we will plot the cureve

# %%
predictions_probability= rfc.predict_proba(testdata)
fpr,tpr,thresholds=roc_curve(y_test, predictions_probability[:,1])

plt.plot(fpr,tpr)
plt.plot([0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()

# %% [markdown]
# As we cna see that our model performed very well in classifying the sentiments, with an accuracy score, precision score and recall score of approx 96%.
#
# Now we will check for custom input as well and let our model identify the sentiment of the input statement.

# %%
def expression_check(prediction_input):
    if prediction_input==0:
        print("Input statement has negative sentiment")
    elif prediction_input==1:
        print("Input statement has positive sentiment")
    else:
        print("Invalid Statement")

# %% [markdown]
# Function to take the input statement and performs the same transformation as we did earlier

# %%
def sentiment_predictor(input):
    input=text_transformation(input)
    transformed_input=cv.transform(input)
    prediction=rfc.predict(transformed_input)
    expression_check(prediction)

# %%
input1=["Sometimes I just don't want to go out"]
input2=["I bought a new phone and it's so good"]

# %%
sentiment_predictor(input1)
sentiment_predictor(input2)
# Out:
# Input statement has negative sentiment
# Input statement has negative sentiment

# %% [markdown]
# # Image Recognition using CNN on CIFAR-10 Dataset

# %% [markdown]
# In this project we will be using CIFAR-10 dataset. This dataset includes thousands of pictures of 10 different kinds of objects like airplanes, automobiles, birds and so on.
#
# Each image in the dataset includes a matching label so we know what kind of image it is.
#
# The images in the CIFAR-10 dataset are only 32x32 pixels.

# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from pathlib import Path
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Load the dataset

# %%
(X_train,y_train),(X_test, y_test)=cifar10.load_data()

# %% [markdown]
# Normalize the data

# %%
X_train=X_train.astype('float32')
X_test=X_test.astype('float32')
X_train/=255.0
X_test/=255.0

# %% [markdown]
# Convert class vectors to binary class matrices

# %%
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),padding='same',input_shape=(32,32,3),activation='relu'))
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),padding='same',activation='relu'))
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10,activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\Mohit Tripathi\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Mohit Tripathi\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# Compile the model

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Mohit Tripathi\AppData\Roaming\Python\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 32)        18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 32)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 32)          0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 512)               590336
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 642570 (2.45 MB)
# Trainable params: 642570 (2.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Train the mdoel

# %%
model.fit(
    X_train,
    y_train,
    batch_size=32,
    epochs=20,
    validation_data=(X_test, y_test),
    shuffle=True)
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.8952 - accuracy: 0.6855 - val_loss: 0.8168 - val_accuracy: 0.7208
# Epoch 2/20
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.8492 - accuracy: 0.7025 - val_loss: 0.7981 - val_accuracy: 0.7270
# Epoch 3/20
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.8163 - accuracy: 0.7127 - val_loss: 0.7452 - val_accuracy: 0.7466
# Epoch 4/20
# 1563/1563 [==============================] - 57s 37ms/step - loss: 0.7900 - accuracy: 0.7256 - val_loss: 0.7298 - val_accuracy: 0.7521
# Epoch 5/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.7653 - accuracy: 0.7290 - val_loss: 0.7070 - val_accuracy: 0.7615
# Epoch 6/20
# 1563/1563 [==============================] - 64s 41ms/step - loss: 0.7434 - accuracy: 0.7389 - val_loss: 0.7076 - val_accuracy: 0.7543
# Epoch 7/20
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.7219 - accuracy: 0.7475 - val_loss: 0.6813 - val_accuracy: 0.7659
# Epoch 8/20
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.7072 - accuracy: 0.7508 - val_loss: 0.7002 - val_accuracy: 0.7643
# Epoch 9/20
# 1563/1563 [==============================] - 79s 50ms/step - loss: 0.6935 - accuracy: 0.7555 - val_loss: 0.6832 - val_accuracy: 0.7688
# Epoch 10/20
# 1563/1563 [==============================] - 63s 40ms/step - loss: 0.6847 - accuracy: 0.7611 - val_loss: 0.6878 - val_accuracy: 0.7632
# Epoch 11/20
# 1563/1563 [==============================] - 60s 38ms/step - loss: 0.6707 - accuracy: 0.7659 - val_loss: 0.6730 - val_accuracy: 0.7708
# Epoch 12/20
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.6605 - accuracy: 0.7683 - val_loss: 0.6884 - val_accuracy: 0.7599
# Epoch 13/20
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.6451 - accuracy: 0.7728 - val_loss: 0.6643 - val_accuracy: 0.7763
# Epoch 14/20
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.6401 - accuracy: 0.7755 - val_loss: 0.6756 - val_accuracy: 0.7687
# Epoch 15/20
# 1563/1563 [==============================] - 75s 48ms/step - loss: 0.6315 - accuracy: 0.7797 - val_loss: 0.6814 - val_accuracy: 0.7681
# Epoch 16/20
# 1563/1563 [==============================] - 63s 41ms/step - loss: 0.6205 - accuracy: 0.7823 - val_loss: 0.6747 - val_accuracy: 0.7697
# Epoch 17/20
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.6185 - accuracy: 0.7839 - val_loss: 0.6549 - val_accuracy: 0.7773
# Epoch 18/20
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.6089 - accuracy: 0.7873 - val_loss: 0.6730 - val_accuracy: 0.7721
# Epoch 19/20
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.5965 - accuracy: 0.7894 - val_loss: 0.6528 - val_accuracy: 0.7774
# Epoch 20/20
# 1563/1563 [==============================] - 59s 38ms/step - loss: 0.5969 - accuracy: 0.7915 - val_loss: 0.6651 - val_accuracy: 0.7775

# %% [markdown]
# Save the neural network architecture

# %%
model_structure=model.to_json()
f=Path("model_structure.json")
f.write_text(model_structure)
# Out:
# 6342

# %% [markdown]
# Save the trained neural network weights

# %%
model.save_weights("model_weight.h5")

# %% [markdown]
# Making Predictions on the images

# %%
from keras.models import model_from_json
from pathlib import Path
from keras.preprocessing import image
import numpy as np

# %%
class_labels=[
    "Planes",
    "car",
    "Bird",
    "Cat",
    "Deer",
    "Dog",
    "Frog",
    "Horse",
    "Boat",
    "Truck"
]

# %% [markdown]
# load the json file that contains the mdoel structure

# %%
f=Path("model_structure.json")
model_structure=f.read_text()

# %% [markdown]
# Recreate the keras modeel bject from the json data

# %%
model=model_from_json(model_structure)

# %% [markdown]
# reload the model training weights

# %%
model.load_weights("model_weight.h5")

# %% [markdown]
# Load an image file to test

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
img=load_img("dog.png",target_size=(32,32))
plt.imshow(img)

# %% [markdown]
# Convert the image to a numpy array

# %%
from tensorflow.keras.utils import img_to_array
image_to_test=img_to_array(img)

# %%
list_of_images=np.expand_dims(image_to_test,axis=0)

# %% [markdown]
# make predictions using the model

# %%
results=model.predict(list_of_images)
# Out:
# 1/1 [==============================] - 0s 224ms/step

# %% [markdown]
# since we are only testing one image, we only need to check the first result

# %%
single_result=results[0]

# %% [markdown]
# We will get a likeliood score for all 10 possible classes. Find out which class has the highest score

# %%
most_likely_class_index=int(np.argmax(single_result))
class_likelihood=single_result[most_likely_class_index]

# %% [markdown]
# Get the name of the most likely class

# %%
class_label=class_labels[most_likely_class_index]

# %% [markdown]
# Print the result

# %%
print("This is a image is a {} likelihood: {:2f}".format(class_label, class_likelihood))
# Out:
# This is a image is a Dog likelihood: 1.000000

# %% [markdown]
# # Chatbot using NLP and Neural Networks in Python

# %% [markdown]
# Tag means classes
#
# Patterns means what user is going to ask
#
# Response is chatbot response

# %%
data={"intents":[
    {"tag":"greeting",
     "patterns":["Hello","How are you?","Hi There","Hi","What's up"],
     "responses":["Howdy Partner!","Hello","How are you doing?","Greetings!","How do you do"]
        },
    {"tag":"age",
     "patterns":["how old are you","when is your birthday","when was you born"],
     "responses":["I am 24 years old","I was born in 1966","My birthday is July 3rd and I was born in 1996","03/07/1996"]
        },
    {"tag":"date",
     "patterns":["what are you doing this weekend",
                "do you want to hangout sometime?","what are your plans for this week"],
     "responses":["I am available this week","I don't have any plans","I am not busy"]
        },
    {"tag":"name",
     "patterns":["what's your name","what are you called","who are you"],
     "responses":["My name is Kippi","I'm Kippi","Kippi"]
        },
    {"tag":"goodbye",
     "patterns":["bye","g2g","see ya","adios","cya"],
     "responses":["It was nice speaking to you","See you later","Speak Soon"]
        },
]}

# %% [markdown]
# For each tag we created, we would specify patterns. Essentially this defines the different ways of how a user may pose a query to the chatbot.
#
# The chatbot would then take these patterns and use them as training data to determine what someone is asking and the chatbot response would be relevant to that qustion.

# %%
import json
import string
import random

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Dropout

nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# In order to create our training data below steps to be followed
#
# Create a vocabulary of all the words used in the patterns
#
# Create a list of the classes- tage of ach intent
#
# Create a list of all the patterns within the intents file
#
# Create a list of all the associated tags to go with each patterns in the intents file.
#
# Initialising lemmatier to get stem of words

# %%
lemmatizer=WordNetLemmatizer()

words=[]
classes=[]
doc_x=[]
doc_y=[]

# %% [markdown]
# Loop through all the intents
#
# Tokenize each patter and append token to words, the patterns and the associated tag to their associated list

# %%
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens=nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_x.append(pattern)
        doc_y.append(intent["tag"])
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# %% [markdown]
# Lemmatize all the words in the vocab and convert them to lowercase

# %%
words=[lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]

# %% [markdown]
# Sorting the vocab and classes in alphabeical order and taking the set to ensure no duplicates occur

# %%
words=sorted(set(words))
classes=sorted(set(classes))

# %%
print(words)
# Out:
# ["'s", 'adios', 'are', 'birthday', 'born', 'bye', 'called', 'cya', 'do', 'doing', 'for', 'g2g', 'hangout', 'hello', 'hi', 'how', 'is', 'name', 'old', 'plan', 'see', 'sometime', 'there', 'this', 'to', 'up', 'wa', 'want', 'week', 'weekend', 'what', 'when', 'who', 'ya', 'you', 'your']

# %%
print(classes)
# Out:
# ['age', 'date', 'goodbye', 'greeting', 'name']

# %%
print(doc_x)
# Out:
# ['Hello', 'How are you?', 'Hi There', 'Hi', "What's up", 'how old are you', 'when is your birthday', 'when was you born', 'what are you doing this weekend', 'do you want to hangout sometime?', 'what are your plans for this week', "what's your name", 'what are you called', 'who are you', 'bye', 'g2g', 'see ya', 'adios', 'cya']

# %%
print(doc_y)
# Out:
# ['greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'age', 'age', 'age', 'date', 'date', 'date', 'name', 'name', 'name', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye']

# %% [markdown]
# List for training data

# %%
training=[]
out_empty=[0]*len(classes)

# creating a bag of words model

for idx, doc in enumerate(doc_x):
    bow=[]
    text=lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    output_row=list(out_empty)
    output_row[classes.index(doc_y[idx])]=1

    training.append([bow, output_row])

random.shuffle(training)

training=np.array(training,dtype=object)

train_X=np.array(list(training[:,0]))
train_y=np.array(list(training[:,1]))

# %% [markdown]
# The model will look at the features and predict the tag asscoiated with the features and then will select an appropiate message/response from the tag.

# %%
input_shape=(len(train_X[0]),)
output_shape=len(train_y[0])

epochs=500

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Create a Sequential model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation='softmax'))

# Create the Adam optimizer with a specified learning rate
adam = tf.keras.optimizers.Adam(learning_rate=0.01)

# Compile the model using the Adam optimizer
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               4736
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13317 (52.02 KB)
# Trainable params: 13317 (52.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.fit(x=train_X, y=train_y, epochs=500, verbose=1)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 990ms/step - loss: 1.6722 - accuracy: 0.0526
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5985 - accuracy: 0.2105
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4593 - accuracy: 0.5263
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3608 - accuracy: 0.6316
# Epoch 5/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2104 - accuracy: 0.6842
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1351 - accuracy: 0.8421
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0175 - accuracy: 0.8421
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8868 - accuracy: 0.8421
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7851 - accuracy: 0.8421
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7715 - accuracy: 0.8421
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6726 - accuracy: 0.8421
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4906 - accuracy: 1.0000
# Epoch 13/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4379 - accuracy: 1.0000
# Epoch 14/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4500 - accuracy: 0.8421
# Epoch 15/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.
500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0170e-05 - accuracy: 1.0000
# Epoch 469/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.0029e-06 - accuracy: 1.0000
# Epoch 470/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3086e-05 - accuracy: 1.0000
# Epoch 471/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.2540e-05 - accuracy: 1.0000
# Epoch 472/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8044e-05 - accuracy: 1.0000
# Epoch 473/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1371e-08 - accuracy: 1.0000
# Epoch 474/500
# 1/1 [==============================] - 0s 8ms/step - loss: 8.7838e-07 - accuracy: 1.0000
# Epoch 475/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0553e-05 - accuracy: 1.0000
# Epoch 476/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8827e-06 - accuracy: 1.0000
# Epoch 477/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1499e-04 - accuracy: 1.0000
# Epoch 478/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3929e-06 - accuracy: 1.0000
# Epoch 479/500
# 1/1 [==============================] - 0s 11ms/step - loss: 1.7476e-04 - accuracy: 1.0000
# Epoch 480/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.3792e-06 - accuracy: 1.0000
# Epoch 481/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0949e-04 - accuracy: 1.0000
# Epoch 482/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.9835e-04 - accuracy: 1.0000
# Epoch 483/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1791e-04 - accuracy: 1.0000
# Epoch 484/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.9346e-05 - accuracy: 1.0000
# Epoch 485/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.4314e-05 - accuracy: 1.0000
# Epoch 486/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0769e-04 - accuracy: 1.0000
# Epoch 487/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2578e-05 - accuracy: 1.0000
# Epoch 488/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3287e-05 - accuracy: 1.0000
# Epoch 489/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5207e-05 - accuracy: 1.0000
# Epoch 490/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.3888e-04 - accuracy: 1.0000
# Epoch 491/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.8723e-05 - accuracy: 1.0000
# Epoch 492/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6762e-05 - accuracy: 1.0000
# Epoch 493/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5230e-04 - accuracy: 1.0000
# Epoch 494/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5120e-05 - accuracy: 1.0000
# Epoch 495/500
# 1/1 [==============================] - 0s 10ms/step - loss: 2.6178e-05 - accuracy: 1.0000
# Epoch 496/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1193e-05 - accuracy: 1.0000
# Epoch 497/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2241e-05 - accuracy: 1.0000
# Epoch 498/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8531e-04 - accuracy: 1.0000
# Epoch 499/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0767e-06 - accuracy: 1.0000
# Epoch 500/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.3733e-06 - accuracy: 1.0000

# %%
def clean_text(text):
    tokens=nltk.word_tokenize(text)
    tokens=[lemmatizer.lemmatize(word) for word in tokens]
    return tokens

def bag_of_words(text,vocab):
    tokens=clean_text(text)
    bow=[0]*len(vocab)
    for w in tokens:
        for idx, word in enumerate(vocab):
            if word==w:
                bow[idx]=1
    return np.array(bow)

# %%
def pred_class(text, vocab,labels):
    bow=bag_of_words(text, vocab)
    result=model.predict(np.array([bow]))[0]
    thresh=0.2
    y_pred=[[idx,res] for idx, res in enumerate(result) if res>thresh]

    y_pred.sort(key=lambda x:x[1], reverse=True)
    return_list=[]
    for r in y_pred:
        return_list.append(labels[r[0]])
    return return_list

def get_response(intents_list, intents_json):
    tag=intents_list[0]
    list_of_intents=intents_json["intents"]
    for i in list_of_intents:
        if i["tag"]==tag:
            result=random.choice(i["responses"])
            break
    return result

# %% [markdown]
# Running the chatbot

# %%
while True:
    message=input("")
    intents=pred_class(message, words, classes)
    result=get_response(intents,data)
    print(result)
# Out:
# hi
